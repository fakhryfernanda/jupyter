# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import time
from alpha_vantage.techindicators import TechIndicators
from utils import *
from sklearn.preprocessing import MinMaxScaler

np.random.seed(1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#       5 import datetime
#       6 import time
# ----> 7 from alpha_vantage.techindicators import TechIndicators
#       8 from utils import *
#       9 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'alpha_vantage'

# %% [markdown]
# #### Obtain price data and technical indicators

# %%
start_date = datetime.datetime(2002, 1, 1)
end_date = datetime.datetime(2022, 1, 1)

ticker = "EA"

history = yf.Ticker(ticker).history(start=start_date, end=end_date)
history["Close"].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 start_date = datetime.datetime(2002, 1, 1)
#       2 end_date = datetime.datetime(2022, 1, 1)
#       4 ticker = "EA"
#
# NameError: name 'datetime' is not defined

# %%
intervals = np.arange(6, 21)
ema = get_ema(ticker, intervals, start_date, end_date)
sma = get_sma(ticker, intervals, start_date, end_date)
wma = get_wma(ticker, intervals, start_date, end_date)
t3 = get_t3(ticker, intervals, start_date, end_date)
rsi = get_rsi(ticker, intervals, start_date, end_date)
willr = get_willr(ticker, intervals, start_date, end_date)
adx = get_adx(ticker, intervals, start_date, end_date)
mom = get_mom(ticker, intervals, start_date, end_date)
cci = get_cci(ticker, intervals, start_date, end_date)
cmo = get_cmo(ticker, intervals, start_date, end_date)
roc = get_roc(ticker, intervals, start_date, end_date)
mfi = get_mfi(ticker, intervals, start_date, end_date)
trix = get_trix(ticker, intervals, start_date, end_date)
dx = get_dx(ticker, intervals, start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 intervals = np.arange(6, 21)
#       2 ema = get_ema(ticker, intervals, start_date, end_date)
#       3 sma = get_sma(ticker, intervals, start_date, end_date)
#
# NameError: name 'np' is not defined

# %%
trima = get_trima(ticker, intervals, start_date, end_date)
# Out:
# --- Obtaining TRIMA ---

# %%
df = pd.concat([history, ema, sma, wma, trima, t3, rsi, willr, adx, mom, cci, cmo, roc, mfi, trix, dx], axis=1)
df = df.dropna()
df = df.drop(["Open", "High", "Low", "Volume", "Dividends", "Stock Splits"], axis=1)
df = df.rename(columns={"Close": "close"})
df.to_csv("EA_15.csv", index_label="date")

# %% [markdown]
# #### Read data and create labels

# %%
df = pd.read_csv("EA_15.csv")
df = df.set_index("date")
df.index = pd.to_datetime(df.index)
df
# Out:
#                  close     ema_6     ema_7     ema_8     ema_9    ema_10  \
# date
# 2002-01-02   29.831154   29.8857   29.9079   29.9311   29.9523   29.9695
# 2002-01-03   30.257881   29.9919   29.9952   30.0036   30.0133   30.0218
# 2002-01-04   31.240339   30.3484   30.3064   30.2783   30.2586   30.2432
# 2002-01-07   29.478857   30.0998   30.0993   30.1005   30.1025   30.1042
# 2002-01-08   29.076939   29.8074   29.8436   29.8729   29.8973   29.9173
# ...                ...       ...       ...       ...       ...       ...
# 2021-12-27  132.860870  131.1931  130.8829  130.6026  130.3558  130.1444
# 2021-12-28  133.290298  131.7908  131.4835  131.1987  130.9417  130.7155
# min      10.866638    11.197500    11.232900    11.265200    11.295200
# 25%      24.691830    24.747325    24.764825    24.804150    24.838150
# 50%      49.659046    49.726050    49.721100    49.710200    49.738600
# 75%      81.236795    81.419675    81.412050    81.319950    81.296925
# max     148.032883   146.603000   146.383400   146.201400   146.016600
#
#             ema_10       ema_11       ema_12       ema_13       ema_14  ...  \
# count  5036.000000  5036.000000  5036.000000  5036.000000  5036.000000  ...
# mean     57.748901    57.738988    57.729091    57.719197    57.709299  ...
# std      37.906418    37.895694    37.885017    37.874367    37.863727  ...
# min      11.323400    11.350300    11.376400    11.401900    11.426800  ...
# 25%      24.863225    24.906775    24.937575    24.959425    24.985900  ...
# 50%      49.716450    49.725550    49.737550    49.756000    49.752850  ...
# 75%      81.266775    81.227475    81.213950    81.130375    81.084375  ...
# max     145.827200   145.636000   145.444500   145.280200   145.113000  ...
#
#              dx_11        dx_12        dx_13        dx_14        dx_15  \
# count  5036.000000  5036.000000  5036.000000  5036.000000  5036.000000
# mean     26.520804    25.429902    24.466555    23.603411    22.830420
# std      18.218356    17.618351    17.083590    16.608055    16.171689
# min       0.027300     0.001300     0.021100     0.003300     0.005000
# 25%      11.444900    10.720175    10.152700     9.798775     9.514750
# 50%      23.546950    22.324550    21.349600    20.510300    19.611800
# 75%      39.058350    37.756375    36.271125    34.981100    34.038175
# max      88.786300    87.838300    86.904700    85.983400    85.073000
#
#              dx_16        dx_17        dx_18        dx_19        dx_20
# count  5036.000000  5036.000000  5036.000000  5036.000000  5036.000000
# mean     22.129612    21.491481    20.914750    20.381940    19.887206
# std      15.773381    15.405579    15.053458    14.727894    14.425891
# min       0.000600     0.000700     0.007200     0.001000     0.007300
# 25%       9.305900     9.043875     8.656475     8.406475     8.196300
# 50%      18.950300    18.329200    17.699450    17.184350    16.731000
# 75%      33.062975    32.020300    31.157900    30.304925    29.484800
# max      84.172300    83.280300    82.396200    81.519400    80.649400
#
# [8 rows x 226 columns]

# %%
num_features = len(df.columns) - 1
shape = (int(np.sqrt(num_features)), int(np.sqrt(num_features)))

# %%
labels = create_labels(df, window_size=3)
# Out:
# --- Creating labels ---
# 5036it [00:01, 3197.66it/s]

# %%
print(f"Sell {sum(labels == 0)}")
print(f"Buy {sum(labels == 1)}")
print(f"Hold {sum(labels == 2)}")
# Out:
# Sell 1298
# Buy 1295
# Hold 2443

# %%
minmax = MinMaxScaler(feature_range=(0, 1))

x = np.array(df.loc[:, "ema_6":"dx_20"])
x_norm = minmax.fit_transform(x)
x_reshaped = reshape_data(x_norm, shape[0], shape[1])

# %%
w = 10
h = 10

fig = plt.figure(figsize=(w, h))
for i in range(1, 7):
    fig.add_subplot(3, 2, i)
    img = x_reshaped[i+400]
    plt.title(f"x_{i+400}")
    plt.imshow(img, cmap="binary")

plt.show()
